# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.style.use('fivethirtyeight')

# %%
credit_card = pd.read_csv('C:/Users/emmik/Downloads/creditcard.csv')
credit_card
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
observations = credit_card['Class'].value_counts()

# %%
observations
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
class_info = pd.Series(observations)
class_info.plot(kind="bar")
plt.show()

# %%
class_info.plot(kind="bar", logy=True)
plt.show()

# %%
class0 = credit_card.loc[credit_card['Class'] == 0, ['V1']]
class1 = credit_card.loc[credit_card['Class'] == 1, ['V1']]
plt.hist(class0['V1'], density=True, bins=20, alpha=0.5, label='Class 0', color='grey')
plt.hist(class1['V1'], density=True, bins=20, alpha=0.5, label='Class 1', color='red')
plt.xlabel('Class')
plt.legend()
plt.show()
